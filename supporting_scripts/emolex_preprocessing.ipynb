# %%
import pandas as pd

# %%
# emolex lexicon preprocessing
df = pd.read_csv('./NRC-Emotion-Lexicon-Wordlevel-v0.92.txt', sep='\t', encoding='utf8')

# %%
df.head(20)
# Out:
#       aback         anger  0
# 0     aback  anticipation  0
# 1     aback       disgust  0
# 2     aback          fear  0
# 3     aback           joy  0
# 4     aback      negative  0
# 5     aback      positive  0
# 6     aback       sadness  0
# 7     aback      surprise  0
# 8     aback         trust  0
# 9    abacus         anger  0
# 10   abacus  anticipation  0
# 11   abacus       disgust  0
# 12   abacus          fear  0
# 13   abacus           joy  0
# 14   abacus      negative  0
# 15   abacus      positive  0
# 16   abacus       sadness  0
# 17   abacus      surprise  0
# 18   abacus         trust  1
# 19  abandon         anger  0

# %%
df.to_csv('./NRC-Emotion-Lexicon-Wordlevel-v0.92-headless.csv', index = False, sep='\t')
